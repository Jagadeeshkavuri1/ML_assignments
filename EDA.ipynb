# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagadeeshkavuri1/ML_assignments/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Roller Coaster Database - Exploratory Data Analysis

# %% [markdown]
# In this notebook we are going to perform EDA on the dataset "Roller Coaster".
#
# This dataset contains 1087 rows and 56 columns.
#
# By the end of this notebook we will be able to understand the interrelation and correlation between ROLLER COASTER name,and their location,speed in mph,tarck length
#
# Let's begin by importing necessary packages needed.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
coast = pd.read_csv('/content/coaster_db.csv')
print(" The basic information of the dataset:")
print(coast.info())
# Out:
#  The basic information of the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
# ...

# %%
print("Number of records and fields are:")
print(coast.shape)
# Out:
# Number of records and fields are:
# (1087, 56)

# %% [markdown]
# What different type of columns are present in this data set ??

# %%
print(coast.columns)
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %% [markdown]
# Brief description of the dataset:

# %%
print(coast.describe())
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# Checking up the first five records,last five records and some random records.

# %%
print("First five records of the dataset:")
coast.head()
# Out:
# First five records of the dataset:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
print("last five records of the dataset:")
coast.tail()
# Out:
# last five records of the dataset:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# ...

# %%
print("random record of the dataset:")
coast.sample()
# Out:
# random record of the dataset:
#                    coaster_name          Length              Speed Location  \
# 769  Possessed (roller coaster)  704 ft (215 m)  70 mph (110 km/h)    Other
#
#     Status Opening date                         Type Manufacturer  \
# 769    NaN          NaN  Steel – Inverted – Launched      Intamin
#
#         Height restriction                    Model  ...   speed1    speed2  \
# 769  52–78 in (132–198 cm)  Twisted Impulse Coaster  ...  70 mph   110 km/h
#
#     speed1_value speed1_unit speed_mph height_value height_unit height_ft  \
# 769         70.0         mph      70.0        180.0          ft       NaN
#
#     Inversions_clean Gforce_clean
# 769                0          3.7
#
# [1 rows x 56 columns]

# %% [markdown]
# Let us see the unique values that are present in the column property area

# %%
print(coast.Type.unique())
# Out:
# ['Wood' 'Other' 'Steel' 'Wood\xa0– Side friction' 'Wood\xa0– Shuttle'
#  'Wood\xa0– Racing' 'Wood\xa0– Out and back' 'Wood\xa0– Wild Mouse'
#  'Steel\xa0– Mine Train' 'Steel\xa0– Dueling' 'Steel\xa0– Kiddie'
#  'Steel\xa0– Enclosed' 'Steel\xa0– Wild Mouse'
#  'Steel\xa0– Dual-tracked\xa0– Enclosed' 'Steel\xa0– Junior'
#  'Steel\xa0– Shuttle' 'Steel\xa0– Racing' 'Steel\xa0– Dueling\xa0– Racing'
#  'Steel\xa0– Launched\xa0– Shuttle' 'Steel\xa0– Stand-up'
#  'Steel\xa0– Shuttle\xa0– Launched' 'Steel\xa0– Suspended'
#  'Steel\xa0– Powered\xa0– Mine Train'
#  'Steel\xa0– Powered\xa0– Virtual reality' 'Steel\xa0– Pipeline'
#  'Steel\xa0– Enclosed\xa0– Bobsled' 'Steel\xa0– Twister'
#  'Steel\xa0– Bobsled' 'Steel\xa0– Wild Mouse\xa0– Enclosed'
#  'Steel\xa0– Powered' 'Wood\xa0– Family' 'Steel\xa0– Boomerang'
#  'Steel\xa0– Shuttle\xa0– Boomerang' 'Steel\xa0– Boomerang\xa0– Shuttle'
#  'Steel\xa0– Indoor' 'Steel\xa0– Floorless Coaster' 'Steel\xa0– Family'
# ...

# %% [markdown]
# Let us check how many null values are missing values are present

# %%
print(coast.isnull().sum())
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
coast['Length'].value_counts()
# Out:
# Length
# 935 ft (285 m)          21
# 1,300 ft (400 m)        10
# 2,800 ft (850 m)         9
# 2,400 ft (730 m)         8
# 3,000 ft (910 m)         8
#                         ..
# 4,631 ft (1,412 m)       1
# 1,099 ft (335 m)         1
# 3,158 ft (963 m)         1
# 2,624.7 ft (800.0 m)     1
# 3,328 ft (1,014 m)       1
# Name: count, Length: 569, dtype: int64

# %%
coast['year_introduced'].value_counts()
# Out:
# year_introduced
# 1999    49
# 2000    47
# 1998    32
# 2011    31
# 2001    30
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
ax = coast['year_introduced'].value_counts().head(12).plot(kind='bar', title='TOP- 12 roller coasters introduced')
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = coast['speed_mph'].plot(kind='hist', bins=20, title='coaster_speed in (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
ax = coast['speed_mph'].plot(kind='kde',title='coaster_speed in (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
coast.plot(kind='scatter',
        x='speed_mph',
        y='height_ft',
        title='Coaster Speed vs. Height')
plt.show()

# %%
ax = sns.scatterplot(x='speed_mph',
                y='height_ft',
                hue='year_introduced',
                data=coast)
ax.set_title('Coaster Speed vs. Height')
plt.show()

# %%
sns.pairplot(coast,
             vars=['year_introduced','speed_mph',
                   'height_ft','Inversions_clean','Gforce_clean'],
            hue='Type_Main')
plt.show()

# %%
sns.jointplot(x="speed_mph", y="height_ft", data=coast, size=5)
plt.show()

# %%
data = coast[['speed_mph']].dropna()
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
sns.boxplot(y=data['speed_mph'], color='lightgreen')
plt.title('Box Plot of Roller Coaster Speeds (mph)', fontsize=14)
plt.ylabel('Speed (mph)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
coast.hist(edgecolor='black',bins = 25, figsize= (12,11))
plt.show()

# %%
data = coast[['speed_mph']].dropna()

# Create the violin plot
plt.figure(figsize=(8, 6))
sns.violinplot(y=data['speed_mph'])
plt.title('Violin Plot of Roller Coaster Speeds (mph)', fontsize=14)
plt.ylabel('Speed (mph)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
data = coast[['speed_mph']].dropna()

# Create the strip plot
plt.figure(figsize=(8, 6))
sns.stripplot(y=data['speed_mph'], color='coral', alpha=0.7)
plt.title('Strip Plot of Roller Coaster Speeds (mph)', fontsize=14)
plt.ylabel('Speed (mph)', fontsize=12)
plt.xlabel('costers', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
data = coast[['speed_mph']].dropna()

# Create a catplot
sns.catplot(data=data, y='speed_mph', kind='strip', height=6, aspect=1, color='purple', alpha=0.7)
plt.title('Catplot of Roller Coaster Speeds (mph)', fontsize=16)
plt.ylabel('Speed (mph)', fontsize=14)
plt.xlabel('Data Points', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
numeric_columns = coast.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_columns.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap of Correlations', fontsize=16)
plt.show()

# %%
data = coast[['Type_Main', 'speed_mph']].dropna()

plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='Type_Main', y='speed_mph', errorbar=None, hue='Type_Main', palette='viridis')

plt.title('Average Speed by Coaster Type', fontsize=16)
plt.xlabel('Coaster Type', fontsize=14)
plt.ylabel('Average Speed (mph)', fontsize=14)
plt.xticks(rotation=45)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
