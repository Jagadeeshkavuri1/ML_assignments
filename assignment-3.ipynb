# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagadeeshkavuri1/ML_assignments/blob/main/assignment-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1) Basic Line Plot

# %% [markdown]
# ##(i)Plot a simple line graph of 𝑦 = 𝑥^2for 𝑥 values ranging from -10 to 10.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-10, 10)
y = x**2
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##(ii)Label the x-axis as "X Values" and the y-axis as "Squared Values."

# %%
plt.xlabel("X Values")
plt.ylabel("Squared Values.")
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##(iii)Add a title to the graph.

# %%
plt.title("squared graph")
plt.plot(x,y)
plt.show()

# %% [markdown]
# #(2). Bar Plot

# %% [markdown]
# ##Create a bar chart showing the marks scored by 5 students: [Sai, 'Vamsi','Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88].

# %%
students = ['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita']
marks = [85, 90, 78, 92, 88]
print("student names",students)
print("marks of the tsudent",marks)
plt.bar(students,marks)
plt.show()
# Out:
# student names ['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita']
# marks of the tsudent [85, 90, 78, 92, 88]

# %% [markdown]
# ##(ii) Add labels to the x-axis and y-axis and give the chart a title.

# %%
plt.xlabel('Students')
plt.ylabel('Marks')
plt.bar(students,marks)
plt.show()
